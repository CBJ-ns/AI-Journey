# %%
# !pip install ultralytics
from ultralytics import YOLO
model = YOLO('yolov8s-seg.pt')
results = model('https://ultralytics.com/images/bus.jpg')
results[0].save('result.jpg')
results2 = model('测试.jpg',conf=0.1)
results2[0].save('my_result_force.jpg')
results3 = model('qunxiang.png')
results3[0].save('qunxiang_result.png')
print('模型在这张图里看到的候选目标：',results[0].boxes.cls)
#  把置信度门槛降到0.01，逼它画出所有可疑的框
results_low_conf = model('测试.jpg',conf=0.01)
results_low_conf[0].save('my_result_001.jpg')
# Out:
# ...
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 tie, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/测试.jpg: 640x384 1 person, 5 bottles, 2 bananas, 1 dining table, 1 toaster, 1 refrigerator, 14.8ms
# Speed: 1.8ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /content/qunxiang.png: 320x640 7 persons, 2 horses, 59.4ms
# Speed: 1.5ms preprocess, 59.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# 模型在这张图里看到的候选目标： tensor([ 0.,  0.,  0.,  5.,  0., 27.], device='cuda:0')
#
# image 1/1 /content/测试.jpg: 640x384 1 person, 19 bottles, 3 cups, 3 bowls, 2 bananas, 2 dining tables, 1 oven, 1 toaster, 3 refrigerators, 2 toothbrushs, 14.9ms
# Speed: 1.6ms preprocess, 14.9ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 384)
# 'my_result_001.jpg'

# %%
from ultralytics import YOLO
my_model = YOLO('runs/segment/train/weights/best.pt')
results = my_model('https://ultralytics.com/images/bus.jpg')
results[0].save('my_frist_trained_result.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
# 'my_frist_trained_result.jpg'

# %%
class MyCrackModel:
  def __init__(self,model_name):
    self.model_name = model_name
    print(f'系统已加载模型：{self.model_name}')
  def detect(self,image_name):
    print(f'模型{self.model_name}正在处理图片：{image_name}')
    return {"crack":True,"confidence":0.99}
crack_detector = MyCrackModel("YOLOv8-Crack")
result = crack_detector.detect('图片.jpg')
print(f'输出结果：{result}')
# Out:
# 系统已加载模型：YOLOv8-Crack
# 模型YOLOv8-Crack正在处理图片：图片.jpg
# 输出结果：{'crack': True, 'confidence': 0.99}

# %%
# !pip install ultralytics

# %%
# !yolo task=segment mode=train data=coco8-seg.yaml model=yolov8n-seg.pt epochs=10
# Out:
# ...
# Ultralytics 8.4.159 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !mv /测试.jpg /content/
# Out:
# mv: cannot stat '/测试.jpg': No such file or directory

# %%
# !mv /qunxiang.png /content/
# Out:
# mv: cannot stat '/qunxiang.png': No such file or directory
