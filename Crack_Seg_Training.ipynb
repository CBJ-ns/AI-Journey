# %%
# !pip install ultralytics
# !yolo task=segment mode=train data=crack_data.yaml model=yolov8n-seg.pt epochs=20
# Out:
# ...
# Ultralytics 8.4.161 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install ultralytics
# !yolo task=segment mode=train data=coco128-seg.yaml model=yolov8n-seg.pt epochs=20
# Out:
# ...
# Ultralytics 8.4.161 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO
my_model = YOLO('runs/segment/train-3/weights/best.pt')
results = my_model('https://ultralytics.com/images/bus.jpg')
results[0].save('my_first_trained_result.jpg')
# Out:
# ...
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bus, 1 skateboard, 8.2ms
# Speed: 37.0ms preprocess, 8.2ms inference, 36.6ms postprocess per image at shape (1, 3, 640, 480)
# 'my_first_trained_result.jpg'
